# %%
import cycpd
import matplotlib.pyplot as plt
import pycpd
import numpy as np
import os
import glob
import shutil
import open3d as o3d
import time
import h5py
import copy
import trimesh
from utils import rotationMatrixToEulerAngles, fixedNumDownSample, voxelDownSample, showPointCloud, surfaceVertices2WatertightO3dMesh, loadAlignedPointGroupsWithIndex, getEigValVecOfSSMByPCA
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
toothIndex = 37
loadDir = r"./data/cpdAlignedData/{}/".format(toothIndex)
alignedPointGroups, alignedPgTags = loadAlignedPointGroupsWithIndex(loadDir)

# %%
eigVal, eigVec, A, meanTrainPointVector = getEigValVecOfSSMByPCA(alignedPointGroups)

# %% [markdown]
# ## TEST

# %%
priorMeanPG = meanTrainPointVector.reshape(-1,3).astype(np.double)
priorMeanMesh = surfaceVertices2WatertightO3dMesh(priorMeanPG)

# %%
testDataIndex = 17
testMeshPath = r"F:\Smartee\dataWithPhoto\format-obj\{}\{}L.obj".format(toothIndex,testDataIndex)
# testRepairedMeshPath = r"F:\Smartee\dataWithPhoto\repaired-obj\{}\{}U.obj".format(toothIndex,testDataIndex)

# %%
testMesh = o3d.io.read_triangle_mesh(testMeshPath)
# testRepairedMesh = o3d.io.read_triangle_mesh(testRepairedMeshPath)

# %%
# print("area ratio :{:.2f}/{:.2f}".format(testMesh.get_surface_area(), testRepairedMesh.get_surface_area()))

# %%
voxelSize = 0.2
v, f = trimesh.remesh.subdivide_to_size(vertices=np.asarray(testMesh.vertices), faces=np.asarray(testMesh.triangles), max_edge=voxelSize, max_iter=10, return_index=False)
# v = voxelDownSample(v, voxelSize)
v = fixedNumDownSample(v, desiredNumOfPoint=2500, leftVoxelSize=1.0, rightVoxelSize=0.1)
print("downsampled test pointcloud shape: ",v.shape)
# Out:
# downsampled test pointcloud shape:  (2500, 3)

# %%
# 显示网格化下采样后的存在缺损的测试点云
showPointCloud(v, windowName="re-sampled data with missing part")

# %%
X = np.array(v,dtype=np.double).copy() #参考点云：存在缺损的测试点云，但是牙龈牙齿分界线完整
Y = priorMeanPG.copy() #移动点云：先验平均点云
reg = cycpd.rigid_registration(**{'X': X, 'Y': Y,'max_iterations':300,'tolerance':1e-4,'verbose':True,'print_reg_params':True}) #缩放刚性配准确定缩放尺寸
TY,(s,r,t) = reg.register()
# Out:
# Iteration:1
# ML: -2071.605; 	ML change (error):  2071.605; 	Sigma^2:     6.359; 	Sigma^2 change:    26.675
# [                                                                        ]
# Iteration:2
# ML: -7425.424; 	ML change (error):  5353.818; 	Sigma^2:     6.102; 	Sigma^2 change:     0.257
# [                                                                        ]
# Iteration:3
# ML: -7486.553; 	ML change (error):    61.129; 	Sigma^2:     5.793; 	Sigma^2 change:     0.309
# [                                                                        ]
# Iteration:4
# ML: -7539.643; 	ML change (error):    53.090; 	Sigma^2:     5.366; 	Sigma^2 change:     0.427
# [                                                                        ]
# Iteration:5
# ML: -7617.674; 	ML change (error):    78.031; 	Sigma^2:     4.818; 	Sigma^2 change:     0.548
# [=                                                                       ]
# Iteration:6
# ML: -7726.800; 	ML change (error):   109.125; 	Sigma^2:     4.182; 	Sigma^2 change:     0.636
# [=                                                                       ]
# Iteration:7
# ML: -7866.726; 	ML change (error):   139.927; 	Sigma^2:     3.527; 	Sigma^2 change:     0.655
# [=                                                                       ]
# Iteration:8
# ML: -8026.681; 	ML change (error):   159.954; 	Sigma^2:     2.926; 	Sigma^2 change:     0.601
# [=                                                                       ]
# Iteration:9
# ML: -8188.725; 	ML change (error):   162.044; 	Sigma^2:     2.423; 	Sigma^2 change:     0.503
# [==                                                                      ]
# Iteration:10
# ML: -8337.567; 	ML change (error):   148.842; 	Sigma^2:     2.023; 	Sigma^2 change:     0.400
# [==                                                                      ]
# Iteration:11
# ML: -8466.128; 	ML change (error):   128.561; 	Sigma^2:     1.711; 	Sigma^2 change:     0.312
# [==                                                                      ]
# Iteration:12
# ML: -8573.876; 	ML change (error):   107.748; 	Sigma^2:     1.469; 	Sigma^2 change:     0.242
# [==                                                                      ]
# Iteration:13
# ML: -8663.233; 	ML change (error):    89.357; 	Sigma^2:     1.279; 	Sigma^2 change:     0.190
# [===                                                                     ]
# Iteration:14
# ML: -8737.224; 	ML change (error):    73.991; 	Sigma^2:     1.128; 	Sigma^2 change:     0.151
# [===                                                                     ]
# Iteration:15
# ML: -8798.487; 	ML change (error):    61.263; 	Sigma^2:     1.008; 	Sigma^2 change:     0.120
# [===                                                                     ]
# Iteration:16
# ML: -8849.064; 	ML change (error):    50.577; 	Sigma^2:     0.911; 	Sigma^2 change:     0.097
# [===                                                                     ]
# Iteration:17
# ML: -8890.526; 	ML change (error):    41.462; 	Sigma^2:     0.833; 	Sigma^2 change:     0.078
# [====                                                                    ]
# Iteration:18
# ML: -8924.167; 	ML change (error):    33.641; 	Sigma^2:     0.770; 	Sigma^2 change:     0.063
# [====                                                                    ]
# Iteration:19
# ML: -8951.153; 	ML change (error):    26.986; 	Sigma^2:     0.718; 	Sigma^2 change:     0.051
# [====                                                                    ]
# Iteration:20
# ML: -8972.580; 	ML change (error):    21.426; 	Sigma^2:     0.677; 	Sigma^2 change:     0.042
# [====                                                                    ]
# Iteration:21
# ML: -8989.469; 	ML change (error):    16.890; 	Sigma^2:     0.643; 	Sigma^2 change:     0.034
# [=====                                                                   ]
# Iteration:22
# ML: -9002.746; 	ML change (error):    13.277; 	Sigma^2:     0.616; 	Sigma^2 change:     0.027
# [=====                                                                   ]
# Iteration:23
# ML: -9013.207; 	ML change (error):    10.461; 	Sigma^2:     0.594; 	Sigma^2 change:     0.022
# [=====                                                                   ]
# Iteration:24
# ML: -9021.513; 	ML change (error):     8.306; 	Sigma^2:     0.575; 	Sigma^2 change:     0.018
# [=====                                                                   ]
# Iteration:25
# ML: -9028.191; 	ML change (error):     6.678; 	Sigma^2:     0.560; 	Sigma^2 change:     0.015
# [======                                                                  ]
# Iteration:26
# ML: -9033.647; 	ML change (error):     5.456; 	Sigma^2:     0.548; 	Sigma^2 change:     0.012
# [======                                                                  ]
# Iteration:27
# ML: -9038.190; 	ML change (error):     4.543; 	Sigma^2:     0.538; 	Sigma^2 change:     0.010
# [======                                                                  ]
# Iteration:28
# ML: -9042.048; 	ML change (error):     3.857; 	Sigma^2:     0.530; 	Sigma^2 change:     0.008
# [======                                                                  ]
# Iteration:29
# ML: -9045.385; 	ML change (error):     3.338; 	Sigma^2:     0.522; 	Sigma^2 change:     0.007
# [======                                                                  ]
# Iteration:30
# ML: -9048.323; 	ML change (error):     2.938; 	Sigma^2:     0.516; 	Sigma^2 change:     0.006
# [=======                                                                 ]
# Iteration:31
# ML: -9050.946; 	ML change (error):     2.623; 	Sigma^2:     0.511; 	Sigma^2 change:     0.005
# [=======                                                                 ]
# Iteration:32
# ML: -9053.316; 	ML change (error):     2.370; 	Sigma^2:     0.507; 	Sigma^2 change:     0.004
# [=======                                                                 ]
# Iteration:33
# ML: -9055.478; 	ML change (error):     2.162; 	Sigma^2:     0.503; 	Sigma^2 change:     0.004
# [=======                                                                 ]
# Iteration:34
# ML: -9057.463; 	ML change (error):     1.985; 	Sigma^2:     0.500; 	Sigma^2 change:     0.003
# [========                                                                ]
# Iteration:35
# ML: -9059.294; 	ML change (error):     1.832; 	Sigma^2:     0.497; 	Sigma^2 change:     0.003
# [========                                                                ]
# Iteration:36
# ML: -9060.991; 	ML change (error):     1.696; 	Sigma^2:     0.495; 	Sigma^2 change:     0.003
# [========                                                                ]
# Iteration:37
# ML: -9062.565; 	ML change (error):     1.575; 	Sigma^2:     0.492; 	Sigma^2 change:     0.002
# [========                                                                ]
# Iteration:38
# ML: -9064.029; 	ML change (error):     1.464; 	Sigma^2:     0.490; 	Sigma^2 change:     0.002
# [=========                                                               ]
# Iteration:39
# ML: -9065.392; 	ML change (error):     1.363; 	Sigma^2:     0.489; 	Sigma^2 change:     0.002
# [=========                                                               ]
# Iteration:40
# ML: -9066.661; 	ML change (error):     1.269; 	Sigma^2:     0.487; 	Sigma^2 change:     0.002
# [=========                                                               ]
# Iteration:41
# ML: -9067.843; 	ML change (error):     1.182; 	Sigma^2:     0.486; 	Sigma^2 change:     0.001
# [=========                                                               ]
# Iteration:42
# ML: -9068.944; 	ML change (error):     1.101; 	Sigma^2:     0.484; 	Sigma^2 change:     0.001
# [==========                                                              ]
# Iteration:43
# ML: -9069.969; 	ML change (error):     1.026; 	Sigma^2:     0.483; 	Sigma^2 change:     0.001
# [==========                                                              ]
# Iteration:44
# ML: -9070.924; 	ML change (error):     0.955; 	Sigma^2:     0.482; 	Sigma^2 change:     0.001
# [==========                                                              ]
# Iteration:45
# ML: -9071.813; 	ML change (error):     0.889; 	Sigma^2:     0.481; 	Sigma^2 change:     0.001
# [==========                                                              ]
# Iteration:46
# ML: -9072.641; 	ML change (error):     0.828; 	Sigma^2:     0.480; 	Sigma^2 change:     0.001
# [===========                                                             ]
# Iteration:47
# ML: -9073.412; 	ML change (error):     0.770; 	Sigma^2:     0.479; 	Sigma^2 change:     0.001
# [===========                                                             ]
# Iteration:48
# ML: -9074.128; 	ML change (error):     0.717; 	Sigma^2:     0.478; 	Sigma^2 change:     0.001
# [===========                                                             ]
# Iteration:49
# ML: -9074.795; 	ML change (error):     0.667; 	Sigma^2:     0.478; 	Sigma^2 change:     0.001
# [===========                                                             ]
# Iteration:50
# ML: -9075.414; 	ML change (error):     0.620; 	Sigma^2:     0.477; 	Sigma^2 change:     0.001
# [============                                                            ]
# Iteration:51
# ML: -9075.990; 	ML change (error):     0.576; 	Sigma^2:     0.476; 	Sigma^2 change:     0.001
# [============                                                            ]
# Iteration:52
# ML: -9076.526; 	ML change (error):     0.535; 	Sigma^2:     0.476; 	Sigma^2 change:     0.001
# [============                                                            ]
# Iteration:53
# ML: -9077.023; 	ML change (error):     0.497; 	Sigma^2:     0.475; 	Sigma^2 change:     0.001
# [============                                                            ]
# Iteration:54
# ML: -9077.485; 	ML change (error):     0.462; 	Sigma^2:     0.475; 	Sigma^2 change:     0.001
# [============                                                            ]
# Iteration:55
# ML: -9077.913; 	ML change (error):     0.429; 	Sigma^2:     0.474; 	Sigma^2 change:     0.000
# [=============                                                           ]
# Iteration:56
# ML: -9078.311; 	ML change (error):     0.398; 	Sigma^2:     0.474; 	Sigma^2 change:     0.000
# [=============                                                           ]
# Iteration:57
# ML: -9078.681; 	ML change (error):     0.369; 	Sigma^2:     0.473; 	Sigma^2 change:     0.000
# [=============                                                           ]
# Iteration:58
# ML: -9079.023; 	ML change (error):     0.343; 	Sigma^2:     0.473; 	Sigma^2 change:     0.000
# [=============                                                           ]
# Iteration:59
# ML: -9079.341; 	ML change (error):     0.318; 	Sigma^2:     0.473; 	Sigma^2 change:     0.000
# [==============                                                          ]
# Iteration:60
# ML: -9079.636; 	ML change (error):     0.295; 	Sigma^2:     0.472; 	Sigma^2 change:     0.000
# [==============                                                          ]
# Iteration:61
# ML: -9079.910; 	ML change (error):     0.273; 	Sigma^2:     0.472; 	Sigma^2 change:     0.000
# [==============                                                          ]
# Iteration:62
# ML: -9080.163; 	ML change (error):     0.253; 	Sigma^2:     0.472; 	Sigma^2 change:     0.000
# [==============                                                          ]
# Iteration:63
# ML: -9080.398; 	ML change (error):     0.235; 	Sigma^2:     0.471; 	Sigma^2 change:     0.000
# [===============                                                         ]
# Iteration:64
# ML: -9080.616; 	ML change (error):     0.218; 	Sigma^2:     0.471; 	Sigma^2 change:     0.000
# [===============                                                         ]
# Iteration:65
# ML: -9080.818; 	ML change (error):     0.202; 	Sigma^2:     0.471; 	Sigma^2 change:     0.000
# [===============                                                         ]
# Iteration:66
# ML: -9081.005; 	ML change (error):     0.187; 	Sigma^2:     0.471; 	Sigma^2 change:     0.000
# [===============                                                         ]
# Iteration:67
# ML: -9081.178; 	ML change (error):     0.173; 	Sigma^2:     0.471; 	Sigma^2 change:     0.000
# [================                                                        ]
# Iteration:68
# ML: -9081.338; 	ML change (error):     0.160; 	Sigma^2:     0.470; 	Sigma^2 change:     0.000
# [================                                                        ]
# Iteration:69
# ML: -9081.487; 	ML change (error):     0.149; 	Sigma^2:     0.470; 	Sigma^2 change:     0.000
# [================                                                        ]
# Iteration:70
# ML: -9081.624; 	ML change (error):     0.138; 	Sigma^2:     0.470; 	Sigma^2 change:     0.000
# [================                                                        ]
# Iteration:71
# ML: -9081.752; 	ML change (error):     0.127; 	Sigma^2:     0.470; 	Sigma^2 change:     0.000
# [=================                                                       ]
# Iteration:72
# ML: -9081.870; 	ML change (error):     0.118; 	Sigma^2:     0.470; 	Sigma^2 change:     0.000
# [=================                                                       ]
# Iteration:73
# ML: -9081.979; 	ML change (error):     0.109; 	Sigma^2:     0.470; 	Sigma^2 change:     0.000
# [=================                                                       ]
# Iteration:74
# ML: -9082.080; 	ML change (error):     0.101; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [=================                                                       ]
# Iteration:75
# ML: -9082.174; 	ML change (error):     0.094; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [==================                                                      ]
# Iteration:76
# ML: -9082.260; 	ML change (error):     0.087; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [==================                                                      ]
# Iteration:77
# ML: -9082.340; 	ML change (error):     0.080; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [==================                                                      ]
# Iteration:78
# ML: -9082.415; 	ML change (error):     0.074; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [==================                                                      ]
# Iteration:79
# ML: -9082.483; 	ML change (error):     0.069; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [==================                                                      ]
# Iteration:80
# ML: -9082.547; 	ML change (error):     0.063; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [===================                                                     ]
# Iteration:81
# ML: -9082.605; 	ML change (error):     0.059; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [===================                                                     ]
# Iteration:82
# ML: -9082.660; 	ML change (error):     0.054; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [===================                                                     ]
# Iteration:83
# ML: -9082.710; 	ML change (error):     0.050; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [===================                                                     ]
# Iteration:84
# ML: -9082.756; 	ML change (error):     0.046; 	Sigma^2:     0.469; 	Sigma^2 change:     0.000
# [====================                                                    ]
# Iteration:85
# ML: -9082.799; 	ML change (error):     0.043; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [====================                                                    ]
# Iteration:86
# ML: -9082.839; 	ML change (error):     0.040; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [====================                                                    ]
# Iteration:87
# ML: -9082.876; 	ML change (error):     0.037; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [====================                                                    ]
# Iteration:88
# ML: -9082.910; 	ML change (error):     0.034; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=====================                                                   ]
# Iteration:89
# ML: -9082.941; 	ML change (error):     0.031; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=====================                                                   ]
# Iteration:90
# ML: -9082.970; 	ML change (error):     0.029; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=====================                                                   ]
# Iteration:91
# ML: -9082.997; 	ML change (error):     0.027; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=====================                                                   ]
# Iteration:92
# ML: -9083.022; 	ML change (error):     0.025; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [======================                                                  ]
# Iteration:93
# ML: -9083.045; 	ML change (error):     0.023; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [======================                                                  ]
# Iteration:94
# ML: -9083.067; 	ML change (error):     0.021; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [======================                                                  ]
# Iteration:95
# ML: -9083.086; 	ML change (error):     0.020; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [======================                                                  ]
# Iteration:96
# ML: -9083.104; 	ML change (error):     0.018; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=======================                                                 ]
# Iteration:97
# ML: -9083.121; 	ML change (error):     0.017; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=======================                                                 ]
# Iteration:98
# ML: -9083.137; 	ML change (error):     0.016; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=======================                                                 ]
# Iteration:99
# ML: -9083.151; 	ML change (error):     0.014; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=======================                                                 ]
# Iteration:100
# ML: -9083.164; 	ML change (error):     0.013; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [========================                                                ]
# Iteration:101
# ML: -9083.177; 	ML change (error):     0.012; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [========================                                                ]
# Iteration:102
# ML: -9083.188; 	ML change (error):     0.011; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [========================                                                ]
# Iteration:103
# ML: -9083.198; 	ML change (error):     0.010; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [========================                                                ]
# Iteration:104
# ML: -9083.208; 	ML change (error):     0.010; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [========================                                                ]
# Iteration:105
# ML: -9083.217; 	ML change (error):     0.009; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=========================                                               ]
# Iteration:106
# ML: -9083.225; 	ML change (error):     0.008; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=========================                                               ]
# Iteration:107
# ML: -9083.233; 	ML change (error):     0.008; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=========================                                               ]
# Iteration:108
# ML: -9083.240; 	ML change (error):     0.007; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [=========================                                               ]
# Iteration:109
# ML: -9083.247; 	ML change (error):     0.007; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [==========================                                              ]
# Iteration:110
# ML: -9083.253; 	ML change (error):     0.006; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [==========================                                              ]
# Iteration:111
# ML: -9083.258; 	ML change (error):     0.006; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [==========================                                              ]
# Iteration:112
# ML: -9083.263; 	ML change (error):     0.005; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [==========================                                              ]
# Iteration:113
# ML: -9083.268; 	ML change (error):     0.005; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [===========================                                             ]
# Iteration:114
# ML: -9083.273; 	ML change (error):     0.004; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [===========================                                             ]
# Iteration:115
# ML: -9083.277; 	ML change (error):     0.004; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [===========================                                             ]
# Iteration:116
# ML: -9083.281; 	ML change (error):     0.004; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [===========================                                             ]
# Iteration:117
# ML: -9083.284; 	ML change (error):     0.003; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [============================                                            ]
# Iteration:118
# ML: -9083.287; 	ML change (error):     0.003; 	Sigma^2:     0.468; 	Sigma^2 change:     0.000
# [============================                                            ]
# Iteration:119
# ML: -9083.290; 	ML change (error):     0.003; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [============================                                            ]
# Iteration:120
# ML: -9083.293; 	ML change (error):     0.003; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [============================                                            ]
# Iteration:121
# ML: -9083.295; 	ML change (error):     0.003; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=============================                                           ]
# Iteration:122
# ML: -9083.298; 	ML change (error):     0.002; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=============================                                           ]
# Iteration:123
# ML: -9083.300; 	ML change (error):     0.002; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=============================                                           ]
# Iteration:124
# ML: -9083.302; 	ML change (error):     0.002; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=============================                                           ]
# Iteration:125
# ML: -9083.304; 	ML change (error):     0.002; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==============================                                          ]
# Iteration:126
# ML: -9083.306; 	ML change (error):     0.002; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==============================                                          ]
# Iteration:127
# ML: -9083.307; 	ML change (error):     0.002; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==============================                                          ]
# Iteration:128
# ML: -9083.309; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==============================                                          ]
# Iteration:129
# ML: -9083.310; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==============================                                          ]
# Iteration:130
# ML: -9083.311; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [===============================                                         ]
# Iteration:131
# ML: -9083.312; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [===============================                                         ]
# Iteration:132
# ML: -9083.313; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [===============================                                         ]
# Iteration:133
# ML: -9083.314; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [===============================                                         ]
# Iteration:134
# ML: -9083.315; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [================================                                        ]
# Iteration:135
# ML: -9083.316; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [================================                                        ]
# Iteration:136
# ML: -9083.317; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [================================                                        ]
# Iteration:137
# ML: -9083.318; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [================================                                        ]
# Iteration:138
# ML: -9083.318; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=================================                                       ]
# Iteration:139
# ML: -9083.319; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=================================                                       ]
# Iteration:140
# ML: -9083.320; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=================================                                       ]
# Iteration:141
# ML: -9083.320; 	ML change (error):     0.001; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=================================                                       ]
# Iteration:142
# ML: -9083.321; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==================================                                      ]
# Iteration:143
# ML: -9083.321; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==================================                                      ]
# Iteration:144
# ML: -9083.321; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==================================                                      ]
# Iteration:145
# ML: -9083.322; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [==================================                                      ]
# Iteration:146
# ML: -9083.322; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [===================================                                     ]
# Iteration:147
# ML: -9083.322; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [===================================                                     ]
# Iteration:148
# ML: -9083.323; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [===================================                                     ]
# Iteration:149
# ML: -9083.323; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [===================================                                     ]
# Iteration:150
# ML: -9083.323; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [====================================                                    ]
# Iteration:151
# ML: -9083.324; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [====================================                                    ]
# Iteration:152
# ML: -9083.324; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [====================================                                    ]
# Iteration:153
# ML: -9083.324; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [====================================                                    ]
# Iteration:154
# ML: -9083.324; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [====================================                                    ]
# Iteration:155
# ML: -9083.324; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=====================================                                   ]
# Iteration:156
# ML: -9083.325; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=====================================                                   ]
# Iteration:157
# ML: -9083.325; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=====================================                                   ]
# Iteration:158
# ML: -9083.325; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [=====================================                                   ]
# Iteration:159
# ML: -9083.325; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [======================================                                  ]
# Iteration:160
# ML: -9083.325; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [======================================                                  ]
# Iteration:161
# ML: -9083.325; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [======================================                                  ]
# Iteration:162
# ML: -9083.325; 	ML change (error):     0.000; 	Sigma^2:     0.467; 	Sigma^2 change:     0.000
# [======================================                                  ]
# ========================================================================
# Registration Performance Metrics
# ========================================================================
# Time to initialize EM: 0.4225320816040039
# Time to initialize registration: 0.0
# Average Expectation Time:                    0.1381 +/- 0.0198
# Average Maximization Time:                   0.0016 +/- 0.0045
# Maximization Times - Per individual step
# Average Update Transform Time:               0.0009 +/- 0.0036
# Average Transform Time:                      0.0000 +/- 0.0002
# Average Update Variance Time:                0.0006 +/- 0.0029
#
# Number of iterations performed:          162
# Error at time of finish:                 9.984880489355419e-05

# %%
reg2 = cycpd.affine_registration(**{'X': X, 'Y': TY,'max_iterations':100,'tolerance':1e-4,'verbose':True,'print_reg_params':True}) #仿射变换配准，保证牙齿轮廓边缘相匹配
TTY,(_B,_t) = reg2.register()
# reg2 = cycpd.deformable_registration(**{'X': X, 'Y': TY,'max_iterations':100,'tolerance':1e-4,'verbose':True,'print_reg_params':True}) #自由变换配准，保证牙齿轮廓边缘相匹配
# TTY,(_G,_w) = reg2.register()
# Out:
# Iteration:1
# ML: -6093.769; 	ML change (error):  6093.769; 	Sigma^2:     5.031; 	Sigma^2 change:     7.312
# [                                                                        ]
# Iteration:2
# ML: -7856.945; 	ML change (error):  1763.176; 	Sigma^2:     3.778; 	Sigma^2 change:     1.254
# [=                                                                       ]
# Iteration:3
# ML: -8281.972; 	ML change (error):   425.027; 	Sigma^2:     2.754; 	Sigma^2 change:     1.024
# [==                                                                      ]
# Iteration:4
# ML: -8740.486; 	ML change (error):   458.514; 	Sigma^2:     2.013; 	Sigma^2 change:     0.741
# [==                                                                      ]
# Iteration:5
# ML: -9126.655; 	ML change (error):   386.169; 	Sigma^2:     1.551; 	Sigma^2 change:     0.462
# [===                                                                     ]
# Iteration:6
# ML: -9396.348; 	ML change (error):   269.693; 	Sigma^2:     1.243; 	Sigma^2 change:     0.308
# [====                                                                    ]
# Iteration:7
# ML: -9631.590; 	ML change (error):   235.243; 	Sigma^2:     0.989; 	Sigma^2 change:     0.254
# [=====                                                                   ]
# Iteration:8
# ML: -9904.889; 	ML change (error):   273.298; 	Sigma^2:     0.764; 	Sigma^2 change:     0.225
# [=====                                                                   ]
# Iteration:9
# ML:-10213.144; 	ML change (error):   308.255; 	Sigma^2:     0.578; 	Sigma^2 change:     0.186
# [======                                                                  ]
# Iteration:10
# ML:-10533.574; 	ML change (error):   320.430; 	Sigma^2:     0.433; 	Sigma^2 change:     0.145
# [=======                                                                 ]
# Iteration:11
# ML:-10863.038; 	ML change (error):   329.464; 	Sigma^2:     0.321; 	Sigma^2 change:     0.112
# [=======                                                                 ]
# Iteration:12
# ML:-11203.128; 	ML change (error):   340.090; 	Sigma^2:     0.237; 	Sigma^2 change:     0.085
# [========                                                                ]
# Iteration:13
# ML:-11546.653; 	ML change (error):   343.525; 	Sigma^2:     0.174; 	Sigma^2 change:     0.063
# [=========                                                               ]
# Iteration:14
# ML:-11884.806; 	ML change (error):   338.153; 	Sigma^2:     0.128; 	Sigma^2 change:     0.046
# [==========                                                              ]
# Iteration:15
# ML:-12213.509; 	ML change (error):   328.702; 	Sigma^2:     0.095; 	Sigma^2 change:     0.033
# [==========                                                              ]
# Iteration:16
# ML:-12533.047; 	ML change (error):   319.538; 	Sigma^2:     0.070; 	Sigma^2 change:     0.024
# [===========                                                             ]
# Iteration:17
# ML:-12843.074; 	ML change (error):   310.027; 	Sigma^2:     0.053; 	Sigma^2 change:     0.018
# [============                                                            ]
# Iteration:18
# ML:-13136.893; 	ML change (error):   293.818; 	Sigma^2:     0.040; 	Sigma^2 change:     0.013
# [============                                                            ]
# Iteration:19
# ML:-13401.893; 	ML change (error):   265.000; 	Sigma^2:     0.031; 	Sigma^2 change:     0.009
# [=============                                                           ]
# Iteration:20
# ML:-13624.570; 	ML change (error):   222.677; 	Sigma^2:     0.025; 	Sigma^2 change:     0.006
# [==============                                                          ]
# Iteration:21
# ML:-13794.879; 	ML change (error):   170.309; 	Sigma^2:     0.021; 	Sigma^2 change:     0.004
# [===============                                                         ]
# Iteration:22
# ML:-13911.398; 	ML change (error):   116.519; 	Sigma^2:     0.018; 	Sigma^2 change:     0.003
# [===============                                                         ]
# Iteration:23
# ML:-13984.176; 	ML change (error):    72.778; 	Sigma^2:     0.017; 	Sigma^2 change:     0.002
# [================                                                        ]
# Iteration:24
# ML:-14028.993; 	ML change (error):    44.818; 	Sigma^2:     0.016; 	Sigma^2 change:     0.001
# [=================                                                       ]
# Iteration:25
# ML:-14058.795; 	ML change (error):    29.801; 	Sigma^2:     0.015; 	Sigma^2 change:     0.001
# [==================                                                      ]
# Iteration:26
# ML:-14081.096; 	ML change (error):    22.302; 	Sigma^2:     0.014; 	Sigma^2 change:     0.000
# [==================                                                      ]
# Iteration:27
# ML:-14099.579; 	ML change (error):    18.482; 	Sigma^2:     0.014; 	Sigma^2 change:     0.000
# [===================                                                     ]
# Iteration:28
# ML:-14115.533; 	ML change (error):    15.954; 	Sigma^2:     0.014; 	Sigma^2 change:     0.000
# [====================                                                    ]
# Iteration:29
# ML:-14128.739; 	ML change (error):    13.206; 	Sigma^2:     0.014; 	Sigma^2 change:     0.000
# [====================                                                    ]
# Iteration:30
# ML:-14139.366; 	ML change (error):    10.627; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [=====================                                                   ]
# Iteration:31
# ML:-14148.395; 	ML change (error):     9.029; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [======================                                                  ]
# Iteration:32
# ML:-14156.430; 	ML change (error):     8.035; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [=======================                                                 ]
# Iteration:33
# ML:-14163.519; 	ML change (error):     7.089; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [=======================                                                 ]
# Iteration:34
# ML:-14169.702; 	ML change (error):     6.183; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [========================                                                ]
# Iteration:35
# ML:-14175.217; 	ML change (error):     5.515; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [=========================                                               ]
# Iteration:36
# ML:-14180.268; 	ML change (error):     5.051; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [=========================                                               ]
# Iteration:37
# ML:-14184.952; 	ML change (error):     4.684; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [==========================                                              ]
# Iteration:38
# ML:-14189.297; 	ML change (error):     4.346; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [===========================                                             ]
# Iteration:39
# ML:-14193.311; 	ML change (error):     4.014; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [============================                                            ]
# Iteration:40
# ML:-14197.009; 	ML change (error):     3.698; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [============================                                            ]
# Iteration:41
# ML:-14200.431; 	ML change (error):     3.422; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [=============================                                           ]
# Iteration:42
# ML:-14203.648; 	ML change (error):     3.216; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [==============================                                          ]
# Iteration:43
# ML:-14206.742; 	ML change (error):     3.094; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [==============================                                          ]
# Iteration:44
# ML:-14209.794; 	ML change (error):     3.052; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [===============================                                         ]
# Iteration:45
# ML:-14212.865; 	ML change (error):     3.071; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [================================                                        ]
# Iteration:46
# ML:-14215.995; 	ML change (error):     3.130; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [=================================                                       ]
# Iteration:47
# ML:-14219.203; 	ML change (error):     3.208; 	Sigma^2:     0.013; 	Sigma^2 change:     0.000
# [=================================                                       ]
# Iteration:48
# ML:-14222.489; 	ML change (error):     3.286; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==================================                                      ]
# Iteration:49
# ML:-14225.839; 	ML change (error):     3.350; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===================================                                     ]
# Iteration:50
# ML:-14229.224; 	ML change (error):     3.385; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [====================================                                    ]
# Iteration:51
# ML:-14232.600; 	ML change (error):     3.376; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [====================================                                    ]
# Iteration:52
# ML:-14235.912; 	ML change (error):     3.312; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=====================================                                   ]
# Iteration:53
# ML:-14239.106; 	ML change (error):     3.195; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [======================================                                  ]
# Iteration:54
# ML:-14242.143; 	ML change (error):     3.037; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [======================================                                  ]
# Iteration:55
# ML:-14245.006; 	ML change (error):     2.863; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=======================================                                 ]
# Iteration:56
# ML:-14247.706; 	ML change (error):     2.700; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [========================================                                ]
# Iteration:57
# ML:-14250.266; 	ML change (error):     2.561; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=========================================                               ]
# Iteration:58
# ML:-14252.709; 	ML change (error):     2.443; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=========================================                               ]
# Iteration:59
# ML:-14255.042; 	ML change (error):     2.333; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==========================================                              ]
# Iteration:60
# ML:-14257.264; 	ML change (error):     2.222; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===========================================                             ]
# Iteration:61
# ML:-14259.378; 	ML change (error):     2.114; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===========================================                             ]
# Iteration:62
# ML:-14261.388; 	ML change (error):     2.010; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [============================================                            ]
# Iteration:63
# ML:-14263.302; 	ML change (error):     1.914; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=============================================                           ]
# Iteration:64
# ML:-14265.123; 	ML change (error):     1.821; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==============================================                          ]
# Iteration:65
# ML:-14266.850; 	ML change (error):     1.727; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==============================================                          ]
# Iteration:66
# ML:-14268.474; 	ML change (error):     1.623; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===============================================                         ]
# Iteration:67
# ML:-14269.981; 	ML change (error):     1.508; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [================================================                        ]
# Iteration:68
# ML:-14271.363; 	ML change (error):     1.381; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [================================================                        ]
# Iteration:69
# ML:-14272.605; 	ML change (error):     1.242; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=================================================                       ]
# Iteration:70
# ML:-14273.693; 	ML change (error):     1.088; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==================================================                      ]
# Iteration:71
# ML:-14274.620; 	ML change (error):     0.927; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===================================================                     ]
# Iteration:72
# ML:-14275.394; 	ML change (error):     0.773; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===================================================                     ]
# Iteration:73
# ML:-14276.034; 	ML change (error):     0.641; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [====================================================                    ]
# Iteration:74
# ML:-14276.567; 	ML change (error):     0.533; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=====================================================                   ]
# Iteration:75
# ML:-14277.017; 	ML change (error):     0.450; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [======================================================                  ]
# Iteration:76
# ML:-14277.403; 	ML change (error):     0.386; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [======================================================                  ]
# Iteration:77
# ML:-14277.742; 	ML change (error):     0.339; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=======================================================                 ]
# Iteration:78
# ML:-14278.047; 	ML change (error):     0.304; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [========================================================                ]
# Iteration:79
# ML:-14278.327; 	ML change (error):     0.280; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [========================================================                ]
# Iteration:80
# ML:-14278.590; 	ML change (error):     0.264; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=========================================================               ]
# Iteration:81
# ML:-14278.844; 	ML change (error):     0.254; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==========================================================              ]
# Iteration:82
# ML:-14279.092; 	ML change (error):     0.248; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===========================================================             ]
# Iteration:83
# ML:-14279.339; 	ML change (error):     0.247; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===========================================================             ]
# Iteration:84
# ML:-14279.587; 	ML change (error):     0.248; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [============================================================            ]
# Iteration:85
# ML:-14279.838; 	ML change (error):     0.250; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=============================================================           ]
# Iteration:86
# ML:-14280.091; 	ML change (error):     0.254; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=============================================================           ]
# Iteration:87
# ML:-14280.349; 	ML change (error):     0.257; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==============================================================          ]
# Iteration:88
# ML:-14280.608; 	ML change (error):     0.259; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===============================================================         ]
# Iteration:89
# ML:-14280.868; 	ML change (error):     0.260; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [================================================================        ]
# Iteration:90
# ML:-14281.128; 	ML change (error):     0.259; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [================================================================        ]
# Iteration:91
# ML:-14281.384; 	ML change (error):     0.256; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=================================================================       ]
# Iteration:92
# ML:-14281.636; 	ML change (error):     0.252; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==================================================================      ]
# Iteration:93
# ML:-14281.882; 	ML change (error):     0.246; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [==================================================================      ]
# Iteration:94
# ML:-14282.122; 	ML change (error):     0.240; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [===================================================================     ]
# Iteration:95
# ML:-14282.356; 	ML change (error):     0.234; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [====================================================================    ]
# Iteration:96
# ML:-14282.586; 	ML change (error):     0.229; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=====================================================================   ]
# Iteration:97
# ML:-14282.811; 	ML change (error):     0.226; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [=====================================================================   ]
# Iteration:98
# ML:-14283.035; 	ML change (error):     0.223; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [======================================================================  ]
# Iteration:99
# ML:-14283.256; 	ML change (error):     0.222; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [======================================================================= ]
# Iteration:100
# ML:-14283.478; 	ML change (error):     0.221; 	Sigma^2:     0.012; 	Sigma^2 change:     0.000
# [========================================================================]
# ========================================================================
# Registration Performance Metrics
# ========================================================================
# Time to initialize EM: 0.4526805877685547
# Time to initialize registration: 0.41341209411621094
# Average Expectation Time:                    0.2413 +/- 0.0536
# Average Maximization Time:                   0.0189 +/- 0.0055
# Maximization Times - Per individual step
# Average Update Transform Time:               0.0186 +/- 0.0055
# Average Transform Time:                      0.0002 +/- 0.0004
# Average Update Variance Time:                0.0002 +/- 0.0004
#
# Number of iterations performed:          100
# Error at time of finish:                 0.2212447812908067

# %%
def showRefAndMovPointClouds(pRef,pMov):
    # X: reference pointcloud, np.array
    # TY: transformed moving pointcloud, np.array
    pcdTY = o3d.geometry.PointCloud()
    pcdTY.points = o3d.utility.Vector3dVector(pMov)
    pcdTY.paint_uniform_color(np.array([1.,0.,0.]))
    pcdX = o3d.geometry.PointCloud()
    pcdX.points = o3d.utility.Vector3dVector(pRef)
    pcdX.paint_uniform_color(np.array([0.,0.,1.]))
    o3d.visualization.draw_geometries([pcdX,pcdTY], window_name="Reference PCL(blue) and Moving PCL(red)", width=800, height=600, left=50,top=50, point_show_normal=False)

# %%
def computeTX(X, s, R, t): #计算反向移动的测试点云
    return 1./s * (X - t) @ R.T

# %%
TX = computeTX(X, s, r, t)

# %%
def getCorrePointPairsWithMinProb(probabilityMatrix, minProb):
    """根据cpd的概率矩阵，获取对应点对"""
    """matProb.shape=(pMovNum,pRefNum)"""
    matProb = probabilityMatrix.copy()
    pointPairs = []
    pRefNum = matProb.shape[1]
    for i in range(pRefNum): #顺序贪婪（快）
        j = np.argmax(matProb[:,i])
        if matProb[j,i] > minProb:
            pointPairs.append((i, j)) # i:ref index, j: mov index
            matProb[j,:] = 0.0
    return np.array(pointPairs, dtype=np.uint32)

def extractCorreMovPoints(pMov, pointPairs):
    return pMov[pointPairs[:,1], :]

def extractCorreRefPoints(pRef, pointPairs):
    return pRef[pointPairs[:,0], :]

# %%
def findOptimalMinProb(matProb, priorPNum, priorMeanMesh, testBrokenMesh, scaleFactor):
    """找到最优的概率阈值使得 priorMeanMesh的选中区域的面积 * scaleFactor^2 == testBrokenMesh的面积"""
    leftProb = 1.0
    rightProb = 0.0
    midProb = (leftProb + rightProb) / 2.
    priorArea = priorMeanMesh.get_surface_area()
    obserArea = testBrokenMesh.get_surface_area()
    pNum = getCorrePointPairsWithMinProb(matProb, midProb).shape[0]
    expectedPNum = obserArea / (priorArea * scaleFactor**2) * priorPNum
    print("expected num of point in test broken pointcloud: ",expectedPNum)
    while np.abs(pNum - expectedPNum) > 1:
        if pNum < expectedPNum:
            leftProb = copy.copy(midProb)
        else:
            rightProb = copy.copy(midProb)
        midProb = (leftProb + rightProb) / 2.
        pNum = getCorrePointPairsWithMinProb(matProb, midProb).shape[0]
    return midProb

# %%
optimalInfProb = findOptimalMinProb(reg2.P, 1500, priorMeanMesh, testMesh, s)
# Out:
# expected num of point in test broken pointcloud:  1126.5541230830142

# %%
pointPairs = getCorrePointPairsWithMinProb(reg2.P, minProb=optimalInfProb)
pointPairsOrder = sorted(range(len(pointPairs)), key=lambda x:pointPairs[x,1]) # 按照先验平均点云的index进行排序
pointPairs = pointPairs[pointPairsOrder]

# %%
pointPairs.shape
# Out:
# (1127, 2)

# %%
pointPairs.shape[0]/priorMeanPG.shape[0] * priorMeanMesh.get_surface_area() * s**2
# Out:
# 165.5984245735067

# %%
testMesh.get_surface_area()
# Out:
# 165.5329085885852

# %%
correY = extractCorreMovPoints(Y, pointPairs)

# %%
correTX = extractCorreRefPoints(TX, pointPairs)
correX = extractCorreRefPoints(X, pointPairs)

# %%
showRefAndMovPointClouds(Y, TX)

# %%
# showRefAndMovPointClouds(X,correX+0.01)

# %%
showRefAndMovPointClouds(correY,correTX) # correY:corresponding priorMeanPG, correTX: corresponding transformed testPG

# %%
# def reconstructMissingPoints(priorMeanVec, priorCovMat, obserVec, obserIndices):
#     # Get the predicted mean vec(predMeanVec), posterior mean vec(posteriorMuX) and covMat(posteriorCovMatXX) of a Gaussian process
#     # X:missing part, Y:observed data, This function works if covMat is non-singular
#     nonObserIndices = np.setdiff1d(np.arange(priorMeanVec.shape[0]), obserIndices, assume_unique=False)
#     assert np.abs(np.linalg.det(covMat))>1e-6, "Covariance matrix is singular."
#     muX = priorMeanVec[nonObserIndices]
#     muY = priorMeanVec[obserIndices]
#     covMatXY = covMat[nonObserIndices[:,None],obserIndices[None,:]]
#     covMatYY = covMat[obserIndices[:,None],obserIndices[None,:]]
#     covMatXX = covMat[nonObserIndices[:,None],nonObserIndices[None,:]]
#     invCovMatYY = np.linalg.inv(covMatYY) #可能不可逆！
#     posteriorMuX = muX + covMatXY @ invCovMatYY @ (obserVec-muY)
#     print(covMatXY @ invCovMatYY @ (obserVec-muY))
#     posteriorCovMatXX = covMatXX - covMatXY @ invCovMatYY @ covMatXY.T
#     predMeanVec = np.zeros(priorMeanVec.shape, priorMeanVec.dtype)
#     predMeanVec[nonObserIndices] = posteriorMuX
#     predMeanVec[obserIndices] = obserVec
#     return predMeanVec, posteriorMuX, posteriorCovMatXX

# %%
obserIndices = np.vstack([3*pointPairs[:,1], 3*pointPairs[:,1]+1, 3*pointPairs[:,1]+2]).T.flatten()
nonObserIndices = np.setdiff1d(np.arange(3*priorMeanPG.shape[0]), obserIndices, assume_unique=False)
print(obserIndices[:9])
print(pointPairs[:3,1])
# Out:
# [ 0  1  2 12 13 14 15 16 17]
# [0 4 5]

# %%
# sampleNum = A.shape[0]
# covMat = 1./(sampleNum-1) * A.T @ A
# print("covMat is non-singular: ",np.linalg.det(covMat)>1e-6)
# reconsTestPG, reconsTestMissingPG, _ = reconstructMissingPoints(priorMeanVec=TY.flatten(), priorCovMat=covMat, obserVec=correX.flatten(), obserIndices=obserIndices)

# %%
# subV @ featureVec = observedVec - observedPriorVecMu 最小二乘解featureVec
numPC2Keep = 60
V = eigVec[:,:numPC2Keep]
subV = eigVec[obserIndices,:numPC2Keep]
subVc = eigVec[nonObserIndices,:numPC2Keep] 
lambd = 0.0 # a small constant to avoid over-fitting while maintaining acceptable residuals
featureVec = np.linalg.inv(subV.T @ subV + lambd*np.identity(numPC2Keep)) @ subV.T @ (correTX - correY).flatten()

# %%
predTX = Y + (featureVec @ V.T).reshape(-1,3)
predX = s * predTX @ r + t

# %%
showRefAndMovPointClouds(X,predX) # X:testPG, predX:predicted resampled testPG

# %%
showRefAndMovPointClouds(Y,predTX) # Y:priorMeanPG, predTX:transformed predicted resampled testPG

# %%
assemX = predX.copy()
assemX[pointPairs[:,1]] = correX

# %%
showRefAndMovPointClouds(X,assemX)

# %%
showPointCloud(predX,"predX")
